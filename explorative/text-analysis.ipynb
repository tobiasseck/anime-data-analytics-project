# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora
from gensim.models.ldamodel import LdaModel
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
from scipy.sparse import csr_matrix

# %%
nltk.download('vader_lexicon')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
reviews_df = pd.read_csv("../data/animes.csv")
reviews_df.head(10)
# Out:
#      uid                               title  \
# 0  28891             Haikyuu!! Second Season
# 1  23273             Shigatsu wa Kimi no Uso
# 2  34599                       Made in Abyss
# 3   5114    Fullmetal Alchemist: Brotherhood
# 4  31758    Kizumonogatari III: Reiketsu-hen
# 5  37510                   Mob Psycho 100 II
# 6    199       Sen to Chihiro no Kamikakushi
# 7  38000                    Kimetsu no Yaiba
# 8  35247          Owarimonogatari 2nd Season
# 9   2904  Code Geass: Hangyaku no Lelouch R2
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
# 5  Shigeo "Mob" Kageyama is now maturing and unde...
# 6  Stubborn, spoiled, and naïve, 10-year-old Chih...
# 7  Ever since the death of his father, the burden...
# 8  Following an encounter with oddity specialist ...
# 9  One year has passed since the Black Rebellion,...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
# 5  ['Action', 'Slice of Life', 'Comedy', 'Superna...
# 6             ['Adventure', 'Supernatural', 'Drama']
# 7  ['Action', 'Demons', 'Historical', 'Shounen', ...
# 8   ['Mystery', 'Comedy', 'Supernatural', 'Vampire']
# 9  ['Action', 'Military', 'Sci-Fi', 'Super Power'...
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
# 2   Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0   8.83
# 3    Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0   9.23
# 4                   Jan 6, 2017       1.0   214621         502    22.0   8.83
# 5    Jan 7, 2019 to Apr 1, 2019      13.0   442310         176    21.0   8.89
# 6                  Jul 20, 2001       1.0   913212          40    20.0   8.90
# 7   Apr 6, 2019 to Sep 28, 2019      26.0   575037         106    19.0   8.92
# 8  Aug 12, 2017 to Aug 13, 2017       7.0   189944         573    18.0   8.93
# 9   Apr 6, 2008 to Sep 28, 2008      25.0   992196          27    17.0   8.93
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/3/671...
# 2  https://cdn.myanimelist.net/images/anime/6/867...
# 3  https://cdn.myanimelist.net/images/anime/1223/...
# 4  https://cdn.myanimelist.net/images/anime/3/815...
# 5  https://cdn.myanimelist.net/images/anime/1918/...
# 6  https://cdn.myanimelist.net/images/anime/6/795...
# 7  https://cdn.myanimelist.net/images/anime/1286/...
# 8  https://cdn.myanimelist.net/images/anime/6/873...
# 9  https://cdn.myanimelist.net/images/anime/4/939...
#
#                                                 link
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1  https://myanimelist.net/anime/23273/Shigatsu_w...
# 2  https://myanimelist.net/anime/34599/Made_in_Abyss
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...
# 4  https://myanimelist.net/anime/31758/Kizumonoga...
# 5  https://myanimelist.net/anime/37510/Mob_Psycho...
# 6  https://myanimelist.net/anime/199/Sen_to_Chihi...
# 7  https://myanimelist.net/anime/38000/Kimetsu_no...
# 8  https://myanimelist.net/anime/35247/Owarimonog...
# 9  https://myanimelist.net/anime/2904/Code_Geass_...

# %%
reviews_df = reviews_df.drop_duplicates(subset=['link'], keep='first')

# %%
def get_sentiment(text):
    if not isinstance(text, str):
        text = ''
    return sid.polarity_scores(text)

sid = SentimentIntensityAnalyzer()

reviews_df['synopsis'] = reviews_df['synopsis'].fillna('')
reviews_df['title_sentiment'] = reviews_df['title'].apply(get_sentiment)
reviews_df['synopsis_sentiment'] = reviews_df['synopsis'].apply(get_sentiment)

reviews_df[['title_neg', 'title_neu', 'title_pos', 'title_compound']] = reviews_df['title_sentiment'].apply(pd.Series)
reviews_df[['synopsis_neg', 'synopsis_neu', 'synopsis_pos', 'synopsis_compound']] = reviews_df['synopsis_sentiment'].apply(pd.Series)

# %%
reviews_df.head()
# Out:
#      uid                             title  \
# 0  28891           Haikyuu!! Second Season
# 1  23273           Shigatsu wa Kimi no Uso
# 2  34599                     Made in Abyss
# 3   5114  Fullmetal Alchemist: Brotherhood
# 4  31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
# 2   Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0   8.83
# 3    Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0   9.23
# 4                   Jan 6, 2017       1.0   214621         502    22.0   8.83
#
#    ...                                    title_sentiment  \
# 0  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  ...  {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'comp...
# 2  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#                                   synopsis_sentiment title_neg title_neu  \
# 0  {'neg': 0.06, 'neu': 0.837, 'pos': 0.103, 'com...     0.000     1.000
# 1  {'neg': 0.031, 'neu': 0.814, 'pos': 0.155, 'co...     0.355     0.645
# 2  {'neg': 0.044, 'neu': 0.802, 'pos': 0.154, 'co...     0.000     1.000
# 3  {'neg': 0.086, 'neu': 0.863, 'pos': 0.05, 'com...     0.000     1.000
# 4  {'neg': 0.087, 'neu': 0.754, 'pos': 0.159, 'co...     0.000     1.000
#
#    title_pos  title_compound  synopsis_neg  synopsis_neu  synopsis_pos  \
# 0        0.0           0.000         0.060         0.837         0.103
# 1        0.0          -0.296         0.031         0.814         0.155
# 2        0.0           0.000         0.044         0.802         0.154
# 3        0.0           0.000         0.086         0.863         0.050
# 4        0.0           0.000         0.087         0.754         0.159
#
#    synopsis_compound
# 0             0.7665
# 1             0.9704
# 2             0.9724
# 3            -0.8201
# 4             0.9390
#
# [5 rows x 22 columns]

# %%
corr_matrix = reviews_df[['episodes', 'members', 'popularity', 'ranked', 'score', 'title_compound', 'synopsis_compound']].corr()

plt.figure(figsize=(10, 8))

sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
stop_words = set(stopwords.words('english'))
stop_words.update(['anime','source'])
reviews_df['synopsis_clean'] = reviews_df['synopsis'].str.replace('[Written by MAL Rewrite]', '', regex=False)

def preprocess(text):
    tokens = [word for word in nltk.word_tokenize(text.lower()) if word.isalpha()]
    tokens = [word for word in tokens if word not in stop_words]
    return tokens

reviews_df['synopsis_tokens'] = reviews_df['synopsis_clean'].apply(preprocess)
dictionary = corpora.Dictionary(reviews_df['synopsis_tokens'])
corpus = [dictionary.doc2bow(text) for text in reviews_df['synopsis_tokens']]

lda_model = LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

lda_vis = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(lda_vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1874021967759263847903834411" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el1874021967759263847903834411_data = {"mdsDat": {"x": [-0.0988917732609308, -0.10444794566051588, -0.02942128038535779, 0.34212240795201715, -0.10936140864521236], "y": [0.03211696659834256, -0.15859647755825906, 0.23131678394929767, -0.03997593650541211, -0.06486133648396904], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [30.709785413783052, 26.879952315136276, 15.581705678094101, 14.344840266726314, 12.48371632626027]}, "tinfo": {"Term": ["school", "series", "episode", "music", "video", "high", "short", "girls", "song", "earth", "film", "animation", "manga", "episodes", "tv", "girl", "world", "club", "movie", "student", "war", "included", "dvd", "love", "special", "animated", "original", "based", "academy", "season", "parents", "animals", "kai", "grandfather", "sisters", "tree", "pet", "fox", "traffic", "enma", "robin", "door", "kuro", "books", "owner", "wife", "youkai", "nello", "fuuka", "milk", "ryou", "gerda", "samatarou", "mayuka", "eat", "saeki", "caring", "sana", "troubles", "think", "town", "string", "little", "child", "mother", "daughter", "shop", "girl", "family", "wanted", "castle", "house", "knows", "dog", "beautiful", "boy", "night", "woman", "home", "father", "lives", "day", "forest", "cat", "life", "sister", "comes", "named", "go", "one", "man", "living", "young", "back", "story", "friends", "love", "ann", "people", "like", "help", "time", "world", "way", "however", "find", "two", "become", "earth", "war", "planet", "ship", "mission", "dragon", "humanity", "energy", "destroy", "holy", "enemy", "army", "threat", "destruction", "crew", "combat", "conflict", "military", "universe", "clan", "mankind", "soldiers", "grail", "duel", "weapon", "warriors", "enemies", "advanced", "pok\u00e9mon", "pirate", "knights", "robot", "organization", "race", "forces", "force", "empire", "fight", "alien", "ancient", "evil", "legendary", "known", "battle", "space", "power", "world", "king", "powerful", "humans", "demon", "called", "human", "city", "must", "save", "years", "order", "one", "ann", "new", "however", "two", "mysterious", "time", "people", "high", "club", "academy", "students", "president", "otaku", "council", "hina", "junior", "baseball", "idols", "keita", "tenchi", "kirino", "yomi", "eita", "fumi", "yuuta", "soccer", "rikka", "mato", "keitaro", "kotarou", "saki", "koyuki", "kyousuke", "masaki", "yuihime", "narumi", "urara", "sara", "school", "teacher", "girls", "student", "class", "talent", "boys", "christmas", "team", "love", "members", "relationship", "idol", "get", "friend", "childhood", "feelings", "two", "first", "friends", "new", "life", "one", "time", "day", "however", "together", "girl", "year", "story", "also", "group", "become", "ann", "episode", "video", "music", "song", "animation", "episodes", "tv", "movie", "included", "dvd", "animated", "released", "bundled", "release", "ova", "aired", "volume", "featuring", "specials", "version", "recap", "volumes", "channel", "minna", "uta", "youtube", "nhk", "album", "edition", "unaired", "television", "short", "manga", "original", "series", "film", "season", "characters", "second", "official", "based", "special", "japanese", "first", "story", "game", "new", "nobita", "doraemon", "pokemon", "pikachu", "digimon", "egg", "momo", "kaito", "rito", "lala", "ganta", "marika", "gunpla", "miyu", "pripara", "holmes", "network", "lots", "kannagi", "lacks", "rainbow", "alola", "marian", "amusement", "goku", "mermaid", "agent", "buildings", "dinosaurs", "france", "lisa", "object", "digital", "maria", "prison", "satoshi", "virtual", "accident", "upon", "mystery", "new", "situation", "world", "battle", "discovers", "solve", "behind", "future", "however", "mysterious", "game", "friends", "ann", "one", "find", "life", "even", "two", "family", "another", "must", "time", "also", "begins", "day", "help", "way"], "Freq": [2429.0, 1823.0, 1172.0, 1072.0, 1065.0, 1075.0, 987.0, 1322.0, 739.0, 1077.0, 824.0, 706.0, 771.0, 658.0, 650.0, 2149.0, 3091.0, 617.0, 587 ...

# %%
def preprocess(text):
    tokens = [word for word in text.lower().split() if word.isalpha() and word not in stop_words]
    return ' '.join(tokens)

reviews_df['synopsis_clean'] = reviews_df['synopsis_clean'].apply(preprocess)

def extract_keywords(text):
    if not text.strip(): 
        return []
    vectorizer = TfidfVectorizer(stop_words='english', max_features=10)
    try:
        tfidf_matrix = vectorizer.fit_transform([text])
        feature_names = vectorizer.get_feature_names_out()
        tfidf_scores = zip(feature_names, tfidf_matrix.toarray()[0])
        sorted_tfidf_scores = sorted(tfidf_scores, key=lambda x: x[1], reverse=True)
        top_keywords = [word for word, score in sorted_tfidf_scores[:5]]
        return top_keywords
    except ValueError:
        return []

reviews_df['keywords'] = reviews_df['synopsis_clean'].apply(extract_keywords)

reviews_df[['title', 'synopsis_clean', 'keywords']].head(10)
# Out:
#                                 title  \
# 0             Haikyuu!! Second Season
# 1             Shigatsu wa Kimi no Uso
# 2                       Made in Abyss
# 3    Fullmetal Alchemist: Brotherhood
# 4    Kizumonogatari III: Reiketsu-hen
# 5                   Mob Psycho 100 II
# 6       Sen to Chihiro no Kamikakushi
# 7                    Kimetsu no Yaiba
# 8          Owarimonogatari 2nd Season
# 9  Code Geass: Hangyaku no Lelouch R2
#
#                                       synopsis_clean  \
# 0  following participation karasuno high school v...
# 1  music accompanies path human prodigious pianis...
# 2  gaping chasm stretching depths filled mysterio...
# 3  order something something equal value must alc...
# 4  helping revive legendary vampire koyomi ararag...
# 5  shigeo kageyama maturing understanding role su...
# 6  chihiro ogino less pleased parents discover ab...
# 7  ever since death burden supporting family fall...
# 8  following encounter oddity specialist izuko hi...
# 9  one year passed since black failed uprising ho...
#
#                                             keywords
# 0          [volleyball, hope, karasuno, team, teams]
# 1        [kousei, music, accompanies, note, passing]
# 2          [chasm, come, mysterious, whistle, white]
# 3  [alphonse, brothers, edward, colonel, equivalent]
# 4       [araragi, vampire, possible, turn, powerful]
# 5      [reigen, supernatural, mob, psychic, remains]
# 6          [parents, chihiro, meets, place, pleased]
# 7       [tanjirou, family, demons, able, mysterious]
# 8    [araragi, student, alarmingly, mystery, oddity]
# 9        [black, accept, masked, mastermind, memory]

# %%
exploded_data = reviews_df[['keywords', 'members', 'popularity', 'ranked', 'score']].explode('keywords')

keyword_metrics = exploded_data.groupby('keywords').agg({
    'members': 'mean',
    'popularity': 'mean',
    'ranked': 'mean',
    'score': 'mean'
}).reset_index()

highest_members = keyword_metrics.sort_values(by='members', ascending=False).head(10)
best_popularity = keyword_metrics.sort_values(by='popularity').head(10)
best_ranking = keyword_metrics.sort_values(by='ranked').head(10)
best_score = keyword_metrics.sort_values(by='score', ascending=False).head(10)

highest_members, best_popularity, best_ranking, best_score
# Out:
# (         keywords    members  popularity  ranked  score
#  8816       mikasa  1754979.0         2.0   111.0  8.470
#  4334   equivalent  1615084.0         4.0     1.0  9.230
#  11955        rize  1346036.0         6.0   674.0  7.930
#  10252    otonashi  1247282.0        10.0   284.0  8.250
#  14656    yukiteru  1205275.0        13.0  1043.0  7.740
#  3604         deus  1205275.0        13.0  1043.0  7.740
#  13549       taiga  1153720.0        14.0   204.0  8.340
#  8983      mitsuha  1139878.0        15.0     4.0  9.090
#  6681        izuku  1123551.5        17.0   129.0  8.475
#  7019       kaneki  1123402.5        24.5  1657.5  7.605,
#           keywords    members  popularity  ranked  score
#  8816       mikasa  1754979.0         2.0   111.0  8.470
#  4334   equivalent  1615084.0         4.0     1.0  9.230
#  11955        rize  1346036.0         6.0   674.0  7.930
#  10252    otonashi  1247282.0        10.0   284.0  8.250
#  14656    yukiteru  1205275.0        13.0  1043.0  7.740
#  3604         deus  1205275.0        13.0  1043.0  7.740
#  13549       taiga  1153720.0        14.0   204.0  8.340
#  8983      mitsuha  1139878.0        15.0     4.0  9.090
#  6681        izuku  1123551.5        17.0   129.0  8.475
#  1146       assiah  1085158.0        17.0  1030.0  7.740,
#            keywords    members  popularity  ranked  score
#  4334    equivalent  1615084.0         4.0     1.0   9.23
#  8983       mitsuha  1139878.0        15.0     4.0   9.09
#  14551       yeager   446370.0       175.0     5.0   9.07
#  8496   masterminds   175423.0       620.0     8.0   9.03
#  12883       shouya   842277.0        53.0    10.0   9.01
#  6292   illusionary   740101.0        64.0    12.0   8.97
#  10324    oversized   579150.0        97.0    13.0   8.97
#  9994    oftentimes   579150.0        97.0    13.0   8.97
#  5721      harusame   139309.0       800.0    15.0   8.94
#  9743        nobume   139309.0       800.0    15.0   8.94,
#            keywords    members  popularity  ranked  score
#  4334    equivalent  1615084.0         4.0     1.0   9.23
#  8983       mitsuha  1139878.0        15.0     4.0   9.09
#  14551       yeager   446370.0       175.0     5.0   9.07
#  8496   masterminds   175423.0       620.0     8.0   9.03
#  12883       shouya   842277.0        53.0    10.0   9.01
#  10324    oversized   579150.0        97.0    13.0   8.97
#  9994    oftentimes   579150.0        97.0    13.0   8.97
#  6292   illusionary   740101.0        64.0    12.0   8.97
#  5721      harusame   139309.0       800.0    15.0   8.94
#  9743        nobume   139309.0       800.0    15.0   8.94)

# %%
def plot_keyword_metrics(df, metric, title):
    plt.figure(figsize=(12, 8))
    sns.barplot(x=metric, y='keywords', data=df, palette='viridis', hue='keywords', dodge=False)
    plt.title(title)
    plt.xlabel(metric.capitalize())
    plt.ylabel('Keywords')
    plt.legend([],[], frameon=False)
    if metric == 'members':
        plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
    
    plt.show()

plot_keyword_metrics(highest_members, 'members', 'Top 20 Keywords by Average Number of Members')
plot_keyword_metrics(best_popularity, 'popularity', 'Top 20 Keywords by Best Popularity')
plot_keyword_metrics(best_ranking, 'ranked', 'Top 20 Keywords by Best Ranking')
plot_keyword_metrics(best_score, 'score', 'Top 20 Keywords by Best Score')

# %%
reviews_df_nan = reviews_df.dropna(subset=['ranked'])

# %%
vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False)
keyword_matrix = vectorizer.fit_transform(reviews_df_nan['keywords'])

popularity = reviews_df_nan['popularity'].values
ranked = reviews_df_nan['ranked'].values

def sparse_corr(x, y):
    x = csr_matrix(x)
    mean_x = np.array(x.mean(axis=0)).flatten()
    mean_y = np.mean(y)
    y_centered = y - mean_y
    y_centered = csr_matrix(y_centered).T
    cov = np.array(x.multiply(y_centered).mean(axis=0)).flatten()
    std_x = np.sqrt(np.array(x.power(2).mean(axis=0) - np.square(mean_x)).flatten())
    std_y = np.std(y)
    corr = cov / (std_x * std_y)
    return corr

corr_popularity = sparse_corr(keyword_matrix, popularity)
corr_ranked = sparse_corr(keyword_matrix, ranked)

keywords = vectorizer.get_feature_names_out()
keyword_corr_df = pd.DataFrame({
    'keyword': keywords,
    'corr_popularity': corr_popularity,
    'corr_ranked': corr_ranked
})

keyword_corr_popularity = keyword_corr_df.reindex(keyword_corr_df['corr_popularity'].abs().sort_values(ascending=False).index).head(20)
keyword_corr_ranking = keyword_corr_df.reindex(keyword_corr_df['corr_ranked'].abs().sort_values(ascending=False).index).head(20)

print("Top Keywords Correlated with Popularity:\n", keyword_corr_popularity.head(10))
print("\nTop Keywords Correlated with Ranking:\n", keyword_corr_ranking.head(10))

def plot_correlations(df, metric, title):
    plt.figure(figsize=(10, 8))
    df.head(20).plot(kind='barh', x='keyword', y=metric, legend=False)
    plt.title(title)
    plt.xlabel('Correlation')
    plt.ylabel('Keywords')
    plt.show()

plot_correlations(keyword_corr_popularity, 'corr_popularity', 'Top 20 Keywords Correlated with Popularity')
plot_correlations(keyword_corr_ranking, 'corr_ranked', 'Top 20 Keywords Correlated with Ranking')
# Out:
# e:\Python\GitHub\anime-data-analytics-project\venv\lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Top Keywords Correlated with Popularity:
#             keyword  corr_popularity  corr_ranked
# 8782         music         0.172795     0.108044
# 4441          film         0.150175     0.136736
# 3846   educational         0.149517     0.136794
# 13423        video         0.146032     0.104878
# 12323         song         0.141686     0.096075
# 697       animated         0.112139     0.087154
# 8387         minna         0.108559     0.085944
# 701      animation         0.103274     0.098934
# 11662       school        -0.101091    -0.068127
# 9086           new        -0.100882    -0.098188
#
# Top Keywords Correlated with Ranking:
#             keyword  corr_popularity  corr_ranked
# 3846   educational         0.149517     0.136794
# 4441          film         0.150175     0.136736
# 8782         music         0.172795     0.108044
# 13423        video         0.146032     0.104878
# 701      animation         0.103274     0.098934
# 9086           new        -0.100882    -0.098188
# 12323         song         0.141686     0.096075
# 11471       safety         0.097375     0.088637
# 697       animated         0.112139     0.087154
# 8387         minna         0.108559     0.085944
