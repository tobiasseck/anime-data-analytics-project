# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
main_df = pd.read_csv("../data/animes_better.csv")
main_df
# Out:
#          uid                                              title  \
# 0      28891                            Haikyuu!! Second Season
# 1      23273                            Shigatsu wa Kimi no Uso
# 2      34599                                      Made in Abyss
# 3       5114                   Fullmetal Alchemist: Brotherhood
# 4      31758                   Kizumonogatari III: Reiketsu-hen
# ...      ...                                                ...
# 16211  10075                                        Naruto x UT
# 16212  35828                                   Miira no Kaikata
# 16213  10378                             Shinryaku!? Ika Musume
# 16214  33082                      Kingsglaive: Final Fantasy XV
# 16215  16934  Chuunibyou demo Koi ga Shitai!: Kirameki no......
#
#                                                 synopsis  \
# 0      Following their participation at the Inter-Hig...
# 1      Music accompanies the path of the human metron...
# ...

# %%
columns_to_drop = ['title', 'aired', 'episodes', 'members', 'ranked', 'score', 'link', 'img_url']
main_df = main_df.drop(columns=columns_to_drop)
main_df
# Out:
#          uid                                           synopsis  \
# 0      28891  Following their participation at the Inter-Hig...
# 1      23273  Music accompanies the path of the human metron...
# 2      34599  The Abyss—a gaping chasm stretching down into ...
# 3       5114  "In order for something to be obtained, someth...
# 4      31758  After helping revive the legendary vampire Kis...
# ...      ...                                                ...
# 16211  10075  All-new animation offered throughout UNIQLO cl...
# 16212  35828  High school student Sora Kashiwagi is accustom...
# 16213  10378  After regaining her squid-like abilities, Ika ...
# 16214  33082  For years, the Niflheim Empire and the kingdom...
# 16215  16934  Although Yuuta Togashi and Rikka Takanashi hav...
#
#                                                    genre  popularity     Type  \
# 0      ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...         141       TV
# ...

# %%
main_df['Producers'] = main_df['Producers'].apply(eval)
main_df['Studios'] = main_df['Studios'].apply(eval)
main_df['Themes'] = main_df['Themes'].apply(eval)
main_df['Streaming Platforms'] = main_df['Streaming Platforms'].apply(eval)

# %%
def plot_correlation_with_popularity(column, title):
    exploded = main_df.explode(column)

    correlation = exploded.groupby(column)['popularity'].mean().sort_values(ascending=False)

    plt.figure(figsize=(16, 8))
    sns.barplot(y=correlation.index, x=correlation.values)
    plt.title(f'Top {title} Correlated with Popularity')
    plt.xlabel('Popularity')
    plt.ylabel(title)
    plt.show()

plot_correlation_with_popularity('Type', 'Types')
plot_correlation_with_popularity('Producers', 'Producers')
plot_correlation_with_popularity('Studios', 'Studios')
plot_correlation_with_popularity('Source', 'Sources')
plot_correlation_with_popularity('Themes', 'Themes')
plot_correlation_with_popularity('Demographic', 'Demographics')
plot_correlation_with_popularity('Streaming Platforms', 'Streaming Platforms')
# Out:
# e:\Python\GitHub\anime-data-analytics-project\venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12539 (\N{KATAKANA MIDDLE DOT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
